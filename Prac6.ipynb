# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import statsmodels.api as sm
#from statsmodels.formula.api import ols
#from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels import *

# %%
data = pd.read_csv("msd.csv")
data =data.dropna()

# %%
data.head()
# Out:
#      TV      Radio  Social Media Influencer       Sales
# 0  16.0   6.566231      2.907983       Mega   54.732757
# 1  13.0   9.237765      2.409567       Mega   46.677897
# 2  41.0  15.886446      2.913410       Mega  150.177829
# 3  83.0  30.020028      6.922304       Mega  298.246340
# 4  15.0   8.437408      1.405998      Micro   56.594181

# %%
ols_formula='Sales~C(TV)' 
print()

# %%
OLS = ols(formula=ols_formula,data=data)

# %%
model = OLS.fit()

# %%
model_results = model.summary()

# %%
model_results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 5.034e+04
# Date:                Tue, 28 Jan 2025   Prob (F-statistic):               0.00
# Time:                        23:26:48   Log-Likelihood:                -11315.
# No. Observations:                4546   AIC:                         2.281e+04
# Df Residuals:                    4455   BIC:                         2.340e+04
# Df Model:                          90
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         35.9164      0.439     81.814      0.000      35.056      36.777
# C(TV)[T.11.0]      3.0008      0.621      4.833      0.000       1.784       4.218
# C(TV)[T.12.0]      6.8309      0.621     11.003      0.000       5.614       8.048
# C(TV)[T.13.0]     11.4288      0.585     19.536      0.000      10.282      12.576
# C(TV)[T.14.0]     14.0357      0.617     22.731      0.000      12.825      15.246
# C(TV)[T.15.0]     17.5634      0.587     29.907      0.000      16.412      18.715
# C(TV)[T.16.0]     20.1293      0.600     33.572      0.000      18.954      21.305
# C(TV)[T.17.0]     24.3936      0.621     39.291      0.000      23.176      25.611
# C(TV)[T.18.0]     27.7956      0.605     45.934      0.000      26.609      28.982
# C(TV)[T.19.0]     31.1252      0.621     50.134      0.000      29.908      32.342
# C(TV)[T.20.0]     35.2193      0.592     59.497      0.000      34.059      36.380
# C(TV)[T.21.0]     38.1688      0.573     66.622      0.000      37.046      39.292
# C(TV)[T.22.0]     42.6426      0.614     69.428      0.000      41.438      43.847
# C(TV)[T.23.0]     46.4100      0.585     79.330      0.000      45.263      47.557
# C(TV)[T.24.0]     49.4303      0.605     81.687      0.000      48.244      50.617
# C(TV)[T.25.0]     53.3494      0.590     90.489      0.000      52.194      54.505
# C(TV)[T.26.0]     56.5669      0.594     95.165      0.000      55.402      57.732
# C(TV)[T.27.0]     60.2633      0.614     98.116      0.000      59.059      61.467
# C(TV)[T.28.0]     63.8399      0.585    109.124      0.000      62.693      64.987
# C(TV)[T.29.0]     67.4428      0.594    113.462      0.000      66.277      68.608
# C(TV)[T.30.0]     70.1598      0.605    115.943      0.000      68.973      71.346
# C(TV)[T.31.0]     74.3050      0.624    119.010      0.000      73.081      75.529
# C(TV)[T.32.0]     77.4104      0.594    130.230      0.000      76.245      78.576
# C(TV)[T.33.0]     81.2221      0.600    135.464      0.000      80.047      82.398
# C(TV)[T.34.0]     84.3974      0.573    147.312      0.000      83.274      85.521
# C(TV)[T.35.0]     88.5084      0.597    148.266      0.000      87.338      89.679
# C(TV)[T.36.0]     92.5623      0.592    156.368      0.000      91.402      93.723
# C(TV)[T.37.0]     95.9353      0.608    157.778      0.000      94.743      97.127
# C(TV)[T.38.0]    100.0401      0.587    170.351      0.000      98.889     101.191
# C(TV)[T.39.0]    102.7252      0.624    164.529      0.000     101.501     103.949
# C(TV)[T.40.0]    106.2092      0.568    187.122      0.000     105.096     107.322
# C(TV)[T.41.0]    110.4181      0.640    172.542      0.000     109.163     111.673
# C(TV)[T.42.0]    112.9622      0.597    189.231      0.000     111.792     114.133
# C(TV)[T.43.0]    116.9698      0.563    207.877      0.000     115.867     118.073
# C(TV)[T.44.0]    120.5009      0.611    197.198      0.000     119.303     121.699
# C(TV)[T.45.0]    123.5278      0.602    205.091      0.000     122.347     124.709
# C(TV)[T.46.0]    127.9390      0.575    222.585      0.000     126.812     129.066
# C(TV)[T.47.0]    131.1635      0.571    229.671      0.000     130.044     132.283
# C(TV)[T.48.0]    134.3931      0.632    212.704      0.000     133.154     135.632
# C(TV)[T.49.0]    138.3011      0.600    230.661      0.000     137.126     139.477
# C(TV)[T.50.0]    141.5609      0.602    235.032      0.000     140.380     142.742
# C(TV)[T.51.0]    145.6854      0.614    237.195      0.000     144.481     146.890
# C(TV)[T.52.0]    148.8402      0.624    238.388      0.000     147.616     150.064
# C(TV)[T.53.0]    152.8015      0.636    240.328      0.000     151.555     154.048
# C(TV)[T.54.0]    156.4352      0.597    262.055      0.000     155.265     157.606
# C(TV)[T.55.0]    159.9545      0.605    264.334      0.000     158.768     161.141
# C(TV)[T.56.0]    163.9663      0.617    265.550      0.000     162.756     165.177
# C(TV)[T.57.0]    167.3510      0.687    243.465      0.000     166.003     168.699
# C(TV)[T.58.0]    170.8918      0.592    288.693      0.000     169.731     172.052
# C(TV)[T.59.0]    174.6988      0.600    291.366      0.000     173.523     175.874
# C(TV)[T.60.0]    177.5680      0.583    304.655      0.000     176.425     178.711
# C(TV)[T.61.0]    182.0636      0.602    302.278      0.000     180.883     183.244
# C(TV)[T.62.0]    184.3726      0.624    295.298      0.000     183.149     185.597
# C(TV)[T.63.0]    188.1904      0.585    321.682      0.000     187.043     189.337
# C(TV)[T.64.0]    191.5516      0.592    323.594      0.000     190.391     192.712
# C(TV)[T.65.0]    195.5949      0.602    324.743      0.000     194.414     196.776
# C(TV)[T.66.0]    199.9242      0.602    331.931      0.000     198.743     201.105
# C(TV)[T.67.0]    202.1105      0.636    317.881      0.000     200.864     203.357
# C(TV)[T.68.0]    205.9712      0.614    335.347      0.000     204.767     207.175
# C(TV)[T.69.0]    209.5018      0.608    344.552      0.000     208.310     210.694
# C(TV)[T.70.0]    213.4980      0.597    357.645      0.000     212.328     214.668
# C(TV)[T.71.0]    216.2012      0.681    317.484      0.000     214.866     217.536
# C(TV)[T.72.0]    220.2612      0.614    358.613      0.000     219.057     221.465
# C(TV)[T.73.0]    224.6131      0.640    350.985      0.000     223.358     225.868
# C(TV)[T.74.0]    227.3405      0.585    388.603      0.000     226.194     228.487
# C(TV)[T.75.0]    230.3359      0.590    390.687      0.000     229.180     231.492
# C(TV)[T.76.0]    234.3631      0.659    355.903      0.000     233.072     235.654
# C(TV)[T.77.0]    238.2698      0.592    402.517      0.000     237.109     239.430
# C(TV)[T.78.0]    241.0674      0.608    396.466      0.000     239.875     242.259
# C(TV)[T.79.0]    245.7497      0.602    408.015      0.000     244.569     246.930
# C(TV)[T.80.0]    248.5824      0.597    416.417      0.000     247.412     249.753
# C(TV)[T.81.0]    252.9096      0.664    381.055      0.000     251.608     254.211
# C(TV)[T.82.0]    255.5716      0.624    409.334      0.000     254.348     256.796
# C(TV)[T.83.0]    259.4201      0.600    432.666      0.000     258.245     260.596
# C(TV)[T.84.0]    263.8794      0.621    425.034      0.000     262.662     265.097
# C(TV)[T.85.0]    266.3989      0.600    444.306      0.000     265.223     267.574
# C(TV)[T.86.0]    270.1295      0.632    427.534      0.000     268.891     271.368
# C(TV)[T.87.0]    272.9816      0.617    442.105      0.000     271.771     274.192
# C(TV)[T.88.0]    277.2993      0.597    464.523      0.000     276.129     278.470
# C(TV)[T.89.0]    281.1589      0.594    473.004      0.000     279.994     282.324
# C(TV)[T.90.0]    284.7105      0.602    472.701      0.000     283.530     285.891
# C(TV)[T.91.0]    288.3295      0.669    430.872      0.000     287.018     289.641
# C(TV)[T.92.0]    292.4714      0.617    473.669      0.000     291.261     293.682
# C(TV)[T.93.0]    294.8329      0.632    466.632      0.000     293.594     296.072
# C(TV)[T.94.0]    298.7184      0.617    483.787      0.000     297.508     299.929
# C(TV)[T.95.0]    302.8491      0.632    479.319      0.000     301.610     304.088
# C(TV)[T.96.0]    306.7234      0.602    509.249      0.000     305.543     307.904
# C(TV)[T.97.0]    310.0337      0.617    502.112      0.000     308.823     311.244
# C(TV)[T.98.0]    312.7277      0.617    506.475      0.000     311.517     313.938
# C(TV)[T.99.0]    316.1471      0.597    529.600      0.000     314.977     317.317
# C(TV)[T.100.0]   319.4382      0.590    541.818      0.000     318.282     320.594
# ==============================================================================
# Omnibus:                        0.277   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.871   Jarque-Bera (JB):                0.230
# Skew:                          -0.004   Prob(JB):                        0.891
# Kurtosis:                       3.034   Cond. No.                         96.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig, axes = plt.subplots(1, 2, figsize = (8,4)) 
residuals = model.resid 
sns.histplot(residuals, ax=axes[0])
# Out:
# <Axes: ylabel='Count'>

# %%
fig = sns.scatterplot(x = model.fittedvalues, y = model.resid)

# %%
sm.stats.anova_lm(model, typ=2)
# Out:
#                 sum_sq      df             F  PR(>F)
# C(TV)     3.928787e+07    90.0  50335.049428     0.0
# Residual  3.863609e+04  4455.0           NaN     NaN
