# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Loan.csv")

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
plt.hist(data["Loan_Amount_Term"])
plt.xlabel("Loan Amount Term")
plt.ylabel("Count")
plt.show()

# %%
plt.boxplot(data["ApplicantIncome"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16c714890>,
#   <matplotlib.lines.Line2D at 0x16c716150>],
#  'caps': [<matplotlib.lines.Line2D at 0x16c714510>,
#   <matplotlib.lines.Line2D at 0x16c686f10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x16c72f410>],
#  'medians': [<matplotlib.lines.Line2D at 0x16c6fbdd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16c75e1d0>],
#  'means': []}

# %%
plt.violinplot(data["CoapplicantIncome"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x16c7f0350>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x16c7e8690>,
#  'cmins': <matplotlib.collections.LineCollection at 0x16c769050>,
#  'cbars': <matplotlib.collections.LineCollection at 0x16c813c10>}

# %%
gender_counts = data['Gender'].value_counts() 
plt.bar(gender_counts.index, gender_counts.values)
# Out:
# <BarContainer object of 2 artists>

# %%
dependents = data['Dependents'].value_counts() 
plt.pie(dependents.values, labels=dependents.index, autopct='1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x16c75e250>,
#   <matplotlib.patches.Wedge at 0x16c401410>,
#   <matplotlib.patches.Wedge at 0x16c6e09d0>,
#   <matplotlib.patches.Wedge at 0x16c6e1010>],
#  [Text(-0.26001432028325183, 1.0688276536690275, '0'),
#   Text(-0.5829656150954456, -0.9328188954005964, '1'),
#   Text(0.5332624941620058, -0.9620972468103819, '2'),
#   Text(1.0608836412772824, -0.29073338244903146, '3+')],
#  [Text(-0.14182599288177372, 0.5829969020012877, '1.1f%'),
#   Text(-0.3179812445975158, -0.5088103065821434, '1.1f%'),
#   Text(0.290870451361094, -0.5247803164420265, '1.1f%'),
#   Text(0.5786638043330631, -0.15858184497219896, '1.1f%')])

# %%
plt.scatter(data["ApplicantIncome"],data["LoanAmount"])

# %%
sns.violinplot(data, x="Property_Area", y="LoanAmount")
# Out:
# <Axes: xlabel='Property_Area', ylabel='LoanAmount'>

# %%
sns.displot(data,x="ApplicantIncome",hue="Married",kind="kde")

# %%
sns.pairplot(data, vars=list(data.columns))

# %%
sns.pairplot(data, vars=['ApplicantIncome', 'Gender', 'Education'])

# %%
sns.heatmap(corr_matrix,annot=True,fmt=".2f", linewidth=.5)
plt.show()

# %%
sns.barplot(data,x="Gender",y="ApplicantIncome",hue="Loan_Status") 
plt.show()

# %%
sns.pairplot(data, vars=list(data.columns))

# %%
numeric_data = data.select_dtypes(include=['number'])
non_numeric_rows = data[~data.applymap(lambda x: isinstance(x, (int, float)) or pd.isna(x))] 
corr_matrix = numeric_data.corr()
plt.figure(figsize=(10,8), dpi =70)
sns.heatmap(corr_matrix,annot=True,fmt=".2f", linewidth=.5)
# Out:
# <Axes: >

# %%
data.hist(bins=50, figsize=(12, 8))
plt.show()
